# %%
import pandas as pd
staff_df=pd.DataFrame([{'Name': 'Kelly','Role':'Director of HR'},{'Name': 'Sally','Role':'Course liasion'},{'Name':'james','Role':'Grader'}])


staff_df=staff_df.set_index('Name')
staff_df.head()
student_df=pd.DataFrame([{'Name': 'Sally','School':'Business'},{'Name': 'Mike','School':'Law liasion'},{'Name':'james','School':'Science'}])
student_df=student_df.set_index('Name')
staff_df
# Out:
#                  Role
# Name
# Kelly  Director of HR
# Sally  Course liasion
# james          Grader

# %%
pd.merge(staff_df,student_df,how="outer",left_index=True,right_index=True)
# Out:
#                  Role       School
# Name
# Kelly  Director of HR          NaN
# Mike              NaN  Law liasion
# Sally  Course liasion     Business
# james          Grader      Science

# %%
pd.merge(staff_df,student_df,how="inner",left_index=True,right_index=True)
# Out:
#                  Role    School
# Name
# Sally  Course liasion  Business
# james          Grader   Science

# %%
pd.merge(staff_df,student_df,how="left",left_index=True,right_index=True)
# Out:
#                  Role    School
# Name
# Kelly  Director of HR       NaN
# Sally  Course liasion  Business
# james          Grader   Science

# %%
pd.merge(staff_df,student_df,how="right",left_index=True,right_index=True)
# Out:
#                  Role       School
# Name
# Sally  Course liasion     Business
# Mike              NaN  Law liasion
# james          Grader      Science

# %%
staff_df=staff_df.reset_index()
student_df=student_df.reset_index()
pd.merge(staff_df,student_df,how="right",on='Name')
# Out:
#     Name            Role       School
# 0  Sally  Course liasion     Business
# 1  james          Grader      Science
# 2   Mike             NaN  Law liasion

# %%
staff_df=pd.DataFrame([{'Name': 'Kelly','Role':'Director of HR','Location':'2'},{'Name': 'Sally','Role':'Course liasion','Location':'1'},{'Name':'james','Role':'Grader','Location':'1'}])
student_df=pd.DataFrame([{'Name': 'Sally','School':'Business','Location':'5'},{'Name': 'Mike','School':'Law liasion','Location':'4'},{'Name':'james','School':'Science','Location':'9'}])
pd.merge(staff_df,student_df,how="right",on='Name')
# Out:
#     Name            Role Location_x       School Location_y
# 0  Sally  Course liasion          1     Business          5
# 1  james          Grader          1      Science          9
# 2   Mike             NaN        NaN  Law liasion          4

# %%
staff_df=pd.DataFrame([{'Name': 'Kelly','Last Name':'Dang','Role':'Director of HR','Location':'2'},{'Name': 'Sally','Last Name':'Teabn','Role':'Course liasion','Location':'1'},{'Name':'james','Last Name':'Ngoc','Role':'Grader','Location':'1'}])
student_df=pd.DataFrame([{'Name': 'Sally','Last Name':'Nghia','School':'Business','Location':'5'},{'Name': 'Mike','Last Name':'tran','School':'Law liasion','Location':'4'},{'Name':'james','Last Name':'Ngoc','School':'Science','Location':'9'}])
pd.merge(staff_df,student_df,how="inner",on=['Name','Last Name'])
# Out:
#     Name Last Name    Role Location_x   School Location_y
# 0  james      Ngoc  Grader          1  Science          9

# %%
# %%capture
df_2011=pd.read_csv("./college_scorecard/MERGED2011_12_PP.csv",error_bad_lines=False)
df_2012=pd.read_csv("./college_scorecard/MERGED2012_13_PP.csv",error_bad_lines=False)
df_2013=pd.read_csv("./college_scorecard/MERGED2013_14_PP.csv",error_bad_lines=False)

# %%
df_2011.head()
# Out:
#      UNITID      OPEID OPEID6                               INSTNM  \
# 0  100654.0   100200.0   1002             Alabama A & M University
# 1  100663.0   105200.0   1052  University of Alabama at Birmingham
# 2  100690.0  2503400.0  25034                   Amridge University
# 3  100706.0   105500.0   1055  University of Alabama in Huntsville
# 4  100724.0   100500.0   1005             Alabama State University
#
#          CITY STABBR         ZIP  ACCREDAGENCY INSTURL NPCURL  ...  \
# 0      Normal     AL       35762           NaN     NaN    NaN  ...
# 1  Birmingham     AL  35294-0110           NaN     NaN    NaN  ...
# 2  Montgomery     AL  36117-3553           NaN     NaN    NaN  ...
# 3  Huntsville     AL       35899           NaN     NaN    NaN  ...
# 4  Montgomery     AL  36104-0271           NaN     NaN    NaN  ...
#
#   OMAWDP8_NOTFIRSTTIME_POOLED_SUPP OMENRUP_NOTFIRSTTIME_POOLED_SUPP  \
# 0                              NaN                              NaN
# ...

# %%
frames=[df_2011,df_2012,df_2013]
